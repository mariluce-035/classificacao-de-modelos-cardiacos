# %%
import pandas as pd

# %%
pd.set_option('display.max_columns',500)
pd.set_option('display.max_rows',500)

# %%
file_path_final_full_dataset = "../Database/df_database_dados_normalizados_aumentados_minmax.csv"
#file_path_new_dataset = "../Database/df_database_dados_normalizados_aumentados_minmax_morfologicos.csv"
file_path_new_dataset = "../Database/df_database_dados_normalizados_aumentados_minmax_morfologicos.csv"

# %%
df_final_full_dataset = pd.read_csv(file_path_final_full_dataset)
df_final_full_dataset.head()
# Out:
#       idade  genero    volume     massa      edl1  edl2      edl3  edl4  \
# 0  0.317647     1.0  0.088660  0.163230  0.004051   0.0  0.145233   0.0
# 1  0.341176     1.0  0.129897  0.190722  0.243038   0.0  0.705065   0.0
# 2  0.294118     1.0  0.125773  0.243986  0.361519   0.0  0.439921   0.0
# 3  0.588235     1.0  0.154639  0.158076  0.000000   0.0  0.121648   0.0
# 4  0.635294     1.0  0.076289  0.099656  0.040000   0.0  0.524081   0.0
#
#        edl5  edl6      edl7  edl8    hough1  hough2    hough3  hough4  \
# 0  0.204617   0.0  0.541572   0.0  0.003559     0.0  0.126543     0.0
# 1  0.000000   0.0  0.000000   0.0  0.227758     0.0  0.695988     0.0
# 2  0.024257   0.0  0.144177   0.0  0.387900     0.0  0.484568     0.0
# 3  0.031690   0.0  0.407845   0.0  0.000000     0.0  0.097222     0.0
# 4  0.000000   0.0  0.064365   0.0  0.032028     0.0  0.495370     0.0
#
#      hough5  hough6    hough7  hough8   spharm1   spharm2   spharm3   spharm4  \
# ...

# %%
df_new_dataset = df_final_full_dataset.drop('idade',axis=1)
df_new_dataset.head()
# Out:
#    genero    volume     massa      edl1  edl2      edl3  edl4      edl5  edl6  \
# 0     1.0  0.088660  0.163230  0.004051   0.0  0.145233   0.0  0.204617   0.0
# 1     1.0  0.129897  0.190722  0.243038   0.0  0.705065   0.0  0.000000   0.0
# 2     1.0  0.125773  0.243986  0.361519   0.0  0.439921   0.0  0.024257   0.0
# 3     1.0  0.154639  0.158076  0.000000   0.0  0.121648   0.0  0.031690   0.0
# 4     1.0  0.076289  0.099656  0.040000   0.0  0.524081   0.0  0.000000   0.0
#
#        edl7  edl8    hough1  hough2    hough3  hough4    hough5  hough6  \
# 0  0.541572   0.0  0.003559     0.0  0.126543     0.0  0.187845     0.0
# 1  0.000000   0.0  0.227758     0.0  0.695988     0.0  0.000000     0.0
# 2  0.144177   0.0  0.387900     0.0  0.484568     0.0  0.030387     0.0
# 3  0.407845   0.0  0.000000     0.0  0.097222     0.0  0.024862     0.0
# 4  0.064365   0.0  0.032028     0.0  0.495370     0.0  0.000000     0.0
#
# ...

# %%
df_new_dataset = df_new_dataset.drop('genero',axis=1)
df_new_dataset.head()
# Out:
#      volume     massa      edl1  edl2      edl3  edl4      edl5  edl6  \
# 0  0.088660  0.163230  0.004051   0.0  0.145233   0.0  0.204617   0.0
# 1  0.129897  0.190722  0.243038   0.0  0.705065   0.0  0.000000   0.0
# 2  0.125773  0.243986  0.361519   0.0  0.439921   0.0  0.024257   0.0
# 3  0.154639  0.158076  0.000000   0.0  0.121648   0.0  0.031690   0.0
# 4  0.076289  0.099656  0.040000   0.0  0.524081   0.0  0.000000   0.0
#
#        edl7  edl8    hough1  hough2    hough3  hough4    hough5  hough6  \
# 0  0.541572   0.0  0.003559     0.0  0.126543     0.0  0.187845     0.0
# 1  0.000000   0.0  0.227758     0.0  0.695988     0.0  0.000000     0.0
# 2  0.144177   0.0  0.387900     0.0  0.484568     0.0  0.030387     0.0
# 3  0.407845   0.0  0.000000     0.0  0.097222     0.0  0.024862     0.0
# 4  0.064365   0.0  0.032028     0.0  0.495370     0.0  0.000000     0.0
#
#      hough7  hough8   spharm1   spharm2   spharm3   spharm4   spharm5  \
# ...

# %%
df_new_dataset = df_new_dataset.reset_index(drop=True)
df_new_dataset.head()
# Out:
#      volume     massa      edl1  edl2      edl3  edl4      edl5  edl6  \
# 0  0.088660  0.163230  0.004051   0.0  0.145233   0.0  0.204617   0.0
# 1  0.129897  0.190722  0.243038   0.0  0.705065   0.0  0.000000   0.0
# 2  0.125773  0.243986  0.361519   0.0  0.439921   0.0  0.024257   0.0
# 3  0.154639  0.158076  0.000000   0.0  0.121648   0.0  0.031690   0.0
# 4  0.076289  0.099656  0.040000   0.0  0.524081   0.0  0.000000   0.0
#
#        edl7  edl8    hough1  hough2    hough3  hough4    hough5  hough6  \
# 0  0.541572   0.0  0.003559     0.0  0.126543     0.0  0.187845     0.0
# 1  0.000000   0.0  0.227758     0.0  0.695988     0.0  0.000000     0.0
# 2  0.144177   0.0  0.387900     0.0  0.484568     0.0  0.030387     0.0
# 3  0.407845   0.0  0.000000     0.0  0.097222     0.0  0.024862     0.0
# 4  0.064365   0.0  0.032028     0.0  0.495370     0.0  0.000000     0.0
#
#      hough7  hough8   spharm1   spharm2   spharm3   spharm4   spharm5  \
# ...

# %%
df_new_dataset.to_csv(file_path_new_dataset, index = False)
